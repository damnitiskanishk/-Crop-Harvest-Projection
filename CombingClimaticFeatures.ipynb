# %%
import numpy as np 
import pandas as pd

# %%
df_1 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\stl1_chickpea.csv")
df_2 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\stl2_chickpea.csv")
df_3 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\stl3_chickpea.csv")
df_4 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\stl4_chickpea.csv")
df_5 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\swvl1_chickpea.csv")
df_6 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\swvl2_chickpea.csv")
df_7 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\swvl3_chickpea.csv")
df_8 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\swvl4_chickpea.csv")
df_9 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\ssr_chickpea.csv")
df_10 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\u10_chickpea.csv")
df_11 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\v10_chickpea.csv")
df_12 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\t2m_chickpea.csv")
df_13 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\d2m_chickpea.csv")
df_14 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\tmax_chickpea.csv")
df_15 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\tmin_chickpea.csv")
df_16 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\rain_chickpea.csv")
df_17 = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\Chickpea\Final\countrain_chickpea.csv")

# %%
# Loop through each dataframe and drop the 'Unnamed: 0' column
for i in range(1, 18):
    df = globals()[f'df_{i}']
    print(i,df.shape)
# Out:
# 1 (825, 10)
# 2 (825, 10)
# 3 (825, 10)
# 4 (825, 10)
# 5 (825, 10)
# 6 (825, 10)
# 7 (825, 10)
# 8 (825, 10)
# 9 (825, 10)
# 10 (825, 10)
# 11 (825, 10)
# 12 (825, 10)
# 13 (825, 10)
# 14 (825, 10)
# 15 (825, 10)
# 16 (825, 10)
# 17 (825, 10)

# %%
# Assuming df_1, df_2, ..., df_17 are already defined DataFrames
# Creating a list of DataFrames
dfs = [df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17]


# Dropping 'Unnamed: 0' column if it exists and sorting each DataFrame by 'latitude', 'longitude', and 'year'
for i in range(len(dfs)):
    if 'Unnamed: 0' in dfs[i].columns:
        dfs[i] = dfs[i].drop(columns=['Unnamed: 0'])
    dfs[i] = dfs[i].sort_values(by=['latitude', 'longitude', 'year']).reset_index(drop=True)

# Now dfs contains the processed DataFrames
# If you need to reassign them to df_1, df_2, ..., df_17, you can do the following:
df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17 = dfs

# %%
# # Loop through each dataframe and drop the 'Unnamed: 0' column
# for i in range(1, 18):
#     df = globals()[f'df_{i}']
#     if 'Unnamed: 0' in df.columns:
#         df.drop('Unnamed: 0', axis=1, inplace=True)
#     globals()[f'df_{i}'] = df

# %%
df_1.columns
# Out:
# Index(['DistrictName', 'latitude', 'longitude', 'year', 'stl1_11', 'stl1_12',
#        'stl1_1', 'stl1_2', 'stl1_3', 'stl1_4'],
#       dtype='object')

# %%
df_10
# Out:
#     DistrictName   latitude  longitude       year    u10_11    u10_12  \
# 0       Banswara  23.476028  74.365154  1997-1998 -0.839916 -1.670914
# 1       Banswara  23.476028  74.365154  1998-1999 -1.011446 -1.253863
# 2       Banswara  23.476028  74.365154  1999-2000 -0.785627 -1.496924
# 3       Banswara  23.476028  74.365154  2000-2001 -0.576877 -1.059260
# 4       Banswara  23.476028  74.365154  2001-2002 -1.088987 -0.825031
# ..           ...        ...        ...        ...       ...       ...
# 820   Ganganagar  29.405480  73.563723  2017-2018 -0.300542  0.173223
# 821   Ganganagar  29.405480  73.563723  2018-2019 -0.374144 -0.575551
# 822   Ganganagar  29.405480  73.563723  2019-2020  0.028303 -0.165940
# 823   Ganganagar  29.405480  73.563723  2020-2021 -0.598546  0.015430
# 824   Ganganagar  29.405480  73.563723  2021-2022 -0.566714 -0.370780
#
#         u10_1     u10_2     u10_3     u10_4
# 0   -1.092694  0.552203  0.552203  1.968487
# ...

# %%
# # Loop through each dataframe and drop the 'Unnamed: 0' column
# for i in range(1, 18):
#     df = globals()[f'df_{i}']
#     print(i,df.shape)

# %%
# # Loop through each dataframe and drop the 'Unnamed: 0' column
# for i in range(1, 18):
#     df = globals()[f'df_{i}']
#     df = df.sort_values(['latitude','longitude','year'])
#     df.reset_index(drop=True)
#     globals()[f'df_{i}'] = df.copy()
#     # globals()[f'df_{i}'].reset_index(drop=True)

# %%
# import pandas as pd

# # Assuming df_1, df_2, ..., df_17 are already defined DataFrames
# # Creating a list of DataFrames
# dfs = [df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17]

# # Sorting each DataFrame by 'latitude', 'longitude', and 'year'
# for i in range(len(dfs)):
#     dfs[i] = dfs[i].sort_values(by=['latitude', 'longitude', 'year']).reset_index(drop=True)

# # Now dfs contains the sorted DataFrames
# # If you need to reassign them to df_1, df_2, ..., df_17, you can do the following:
# df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17 = dfs

# %%
df_13
# Out:
#     DistrictName   latitude  longitude       year     d2m_11     d2m_12  \
# 0       Banswara  23.476028  74.365154  1997-1998  15.136309  12.920915
# 1       Banswara  23.476028  74.365154  1998-1999  12.974330   7.719932
# 2       Banswara  23.476028  74.365154  1999-2000   9.003570   5.888279
# 3       Banswara  23.476028  74.365154  2000-2001   8.298242   3.023873
# 4       Banswara  23.476028  74.365154  2001-2002   5.557252   5.598929
# ..           ...        ...        ...        ...        ...        ...
# 820   Ganganagar  29.405480  73.563723  2017-2018  11.991437   6.002179
# 821   Ganganagar  29.405480  73.563723  2018-2019  10.870623   6.694438
# 822   Ganganagar  29.405480  73.563723  2019-2020  13.033617   7.237049
# 823   Ganganagar  29.405480  73.563723  2020-2021   9.571178   7.445737
# 824   Ganganagar  29.405480  73.563723  2021-2022  10.292640   7.984286
#
#         d2m_1      d2m_2      d2m_3      d2m_4
# 0    8.087163   6.729643   7.436764  11.205512
# ...

# %%
# Process df_2 to df_17
for i in range(1, len(dfs)):
    # Drop 'latitude', 'longitude', and 'year' columns
    dfs[i] = dfs[i].drop(columns=['latitude', 'longitude', 'year','DistrictName'])

# If you need to reassign them to df_1, df_2, ..., df_17, you can do the following:
df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17 = dfs

# %%
df_2
# Out:
#        stl2_11    stl2_12     stl2_1     stl2_2     stl2_3     stl2_4
# 0    25.961717  21.036720  21.196228  23.138172  27.189504  32.870337
# 1    24.397693  21.571260  20.817535  24.296281  28.012093  32.976691
# 2    25.558162  22.186711  22.459103  23.233472  27.521565  33.825521
# 3    26.963256  23.318844  22.630413  24.804552  28.988883  33.003332
# 4    26.894615  24.022964  22.617619  23.978152  29.219011  33.635507
# ..         ...        ...        ...        ...        ...        ...
# 820  23.919257  17.788286  17.450883  20.729125  26.451057  31.668084
# 821  24.713265  18.504721  16.348079  17.751704  22.792580  31.087595
# 822  23.496104  15.973405  14.203798  18.920939  22.710550  28.967429
# 823  22.680827  17.460582  15.278108  20.785961  26.595122  29.955446
# 824  22.973644  17.972158  14.904470  18.629935  26.525717  32.926852
#
# [825 rows x 6 columns]

# %%
# for i in range(2, 18):
#     df = globals()[f'df_{i}']
#     df = df.drop(columns=['latitude','longitude','year','DistrictName'])
#     globals()[f'df_{i}'] = df

# %%
df = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10,df_11,df_12,df_13,df_14,df_15,df_16,df_17],axis=1)

# %%
import math
# df['rh_7'] = 100 * np.exp(5423 * ((1 / (df['t2m_7'] + 273.15)) - (1 / (df['d2m_7'] + 273.15))))
# df['rh_8'] = 100 * np.exp(5423 * ((1 / (df['t2m_8'] + 273.15)) - (1 / (df['d2m_8'] + 273.15))))
# df['rh_9'] = 100 * np.exp(5423 * ((1 / (df['t2m_9'] + 273.15)) - (1 / (df['d2m_9'] + 273.15))))
# df['rh_10'] = 100 * np.exp(5423 * ((1 / (df['t2m_10'] + 273.15)) - (1 / (df['d2m_10'] + 273.15))))

df['rh_11'] = 100 * np.exp(5423 * ((1 / (df['t2m_11'] + 273.15)) - (1 / (df['d2m_11'] + 273.15))))
df['rh_12'] = 100 * np.exp(5423 * ((1 / (df['t2m_12'] + 273.15)) - (1 / (df['d2m_12'] + 273.15))))
df['rh_1'] = 100 * np.exp(5423 * ((1 / (df['t2m_1'] + 273.15)) - (1 / (df['d2m_1'] + 273.15))))
df['rh_2'] = 100 * np.exp(5423 * ((1 / (df['t2m_2'] + 273.15)) - (1 / (df['d2m_2'] + 273.15))))
df['rh_3'] = 100 * np.exp(5423 * ((1 / (df['t2m_3'] + 273.15)) - (1 / (df['d2m_3'] + 273.15))))
df['rh_4'] = 100 * np.exp(5423 * ((1 / (df['t2m_4'] + 273.15)) - (1 / (df['d2m_4'] + 273.15))))

# %%
df = df.drop(columns=['t2m_11','t2m_12','t2m_1','t2m_2','t2m_3','t2m_4','d2m_11','d2m_12','d2m_1','d2m_2','d2m_3','d2m_4'])

# %%
df
# Out:
#     DistrictName   latitude  longitude       year    stl1_11    stl1_12  \
# 0       Banswara  23.476028  74.365154  1997-1998  25.693202  20.281856
# 1       Banswara  23.476028  74.365154  1998-1999  23.865524  20.934337
# 2       Banswara  23.476028  74.365154  1999-2000  25.111040  21.590521
# 3       Banswara  23.476028  74.365154  2000-2001  26.527940  22.679671
# 4       Banswara  23.476028  74.365154  2001-2002  26.476361  23.533064
# ..           ...        ...        ...        ...        ...        ...
# 820   Ganganagar  29.405480  73.563723  2017-2018  22.162882  16.181832
# 821   Ganganagar  29.405480  73.563723  2018-2019  23.311329  16.511425
# 822   Ganganagar  29.405480  73.563723  2019-2020  21.904866  14.292111
# 823   Ganganagar  29.405480  73.563723  2020-2021  21.029517  15.939311
# 824   Ganganagar  29.405480  73.563723  2021-2022  21.598840  16.212173
#
#         stl1_1     stl1_2     stl1_3     stl1_4  ...  countrain_1  \
# ...

# %%
df_yield = pd.read_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Yield data\Rajasthan_ChickPea_Yield.csv")

# %%
# Convert to lowercase and remove spaces
df_yield['DistrictName'] = df_yield['DistrictName'].astype(str).str.lower().str.replace(' ', '')
df['DistrictName'] = df['DistrictName'].astype(str).str.lower().str.replace(' ', '')

# %%
df_yield['year'] = df_yield['year'].astype(str).str.split('-').str[0]
df['year_mask'] = df['year'].astype(str).str.split('-').str[0]

# %%
print(df_yield[['DistrictName', 'year']].dtypes)
print(df[['DistrictName', 'year_mask']].dtypes)
# Out:
# DistrictName    object
# year            object
# dtype: object
# DistrictName    object
# year_mask       object
# dtype: object

# %%
df_yield
# Out:
#     DistrictName   year  Yield(Tonnes/Hectares)
# 0          ajmer   1997                    0.95
# 1          ajmer   1998                    0.54
# 2          ajmer   1999                    0.39
# 3          ajmer   2000                    0.29
# 4          ajmer   2001                    0.61
# ..           ...    ...                     ...
# 742      udaipur   2015                    1.09
# 743      udaipur   2016                    1.37
# 744      udaipur   2017                    1.20
# 745      udaipur   2018                    1.32
# 746      udaipur   2019                    1.38
#
# [747 rows x 3 columns]

# %%
df_yield.shape
# Out:
# (747, 3)

# %%
df_yield = df_yield.dropna(subset=['Yield(Tonnes/Hectares)'])

# %%
df_yield.shape
# Out:
# (747, 3)

# %%
df_yield['year'] = df_yield['year'].astype('int64')
df['year_mask'] = df['year_mask'].astype('int64')

# %%
yield_mapping = dict(zip(zip(df_yield['DistrictName'], df_yield['year']), df_yield['Yield(Tonnes/Hectares)']))

# %%
# Map district_name based on rounded latitude and longitude in df1
df['Yield(tonnes/hectare)'] = df.apply(lambda row: yield_mapping.get((row['DistrictName'], row['year_mask']), None ), axis=1)

# %%
percentage_nan = (df['Yield(tonnes/hectare)'].isnull().sum() / len(df)) * 100

print(f"Percentage of NaN values in 'Yield(tonnes/hectare)': {percentage_nan:.2f}%")
# Out:
# Percentage of NaN values in 'Yield(tonnes/hectare)': 9.45%

# %%
df
# Out:
#     DistrictName   latitude  longitude       year    stl1_11    stl1_12  \
# 0       banswara  23.476028  74.365154  1997-1998  25.693202  20.281856
# 1       banswara  23.476028  74.365154  1998-1999  23.865524  20.934337
# 2       banswara  23.476028  74.365154  1999-2000  25.111040  21.590521
# 3       banswara  23.476028  74.365154  2000-2001  26.527940  22.679671
# 4       banswara  23.476028  74.365154  2001-2002  26.476361  23.533064
# ..           ...        ...        ...        ...        ...        ...
# 820   ganganagar  29.405480  73.563723  2017-2018  22.162882  16.181832
# 821   ganganagar  29.405480  73.563723  2018-2019  23.311329  16.511425
# 822   ganganagar  29.405480  73.563723  2019-2020  21.904866  14.292111
# 823   ganganagar  29.405480  73.563723  2020-2021  21.029517  15.939311
# 824   ganganagar  29.405480  73.563723  2021-2022  21.598840  16.212173
#
#         stl1_1     stl1_2     stl1_3     stl1_4  ...  countrain_3  \
# ...

# %%
df.to_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Final Data\ChickPea\ChickPea_Rajasthan.csv",index=False)

# %%
# df.to_csv(r"C:\Users\Kanishk Goyal\OneDrive - IIT Kanpur\Desktop\Prof. Hamim Zafar\Data\Regridding Data\Rajasthan\July-October\FinalFeatures_Rajasthan.csv",index=False)
